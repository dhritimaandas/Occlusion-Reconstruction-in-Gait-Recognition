# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
path='/content/gdrive/My Drive/Results_GAIT/tum_mat/d1_1.mat'

# %%
from scipy.io import loadmat
x=loadmat(path)

# %%
x.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', '002', '007', '001', '003', '006', '004', '008', '010', '009', '005', '011', '020', '015', '019', '017', '013', '014', '016', '012', '018', '024', '025', '021', '028', '026', '027', '030', '022', '023', '029', '031', '034', '035', '033', '032'])

# %%
names=['002', '007', '001', '003', '006', '004', '008', '010', '009', '005', '011', '020', '015', '019', '017', '013', '014', '016', '012', '018', '024', '025', '021', '028', '026', '027', '030', '022', '023', '029', '031', '034', '035', '033', '032']

# %%
arr=[]
for i in range(len(names)):
  arr.append(x[names[i]])

# %%
arr=np.asarray(arr)
arr.shape
# Out:
# (35,)

# %%
temp=[]
num_=[]
for i in range(len(arr)):
  if i>15:
    for j in range(len(arr[i])):
      temp.append(arr[i][j].flatten())
    num_.append(len(arr[i]))
    
num_=np.asarray(num_)

# %%
temp=np.asarray(temp)

# %%
temp.shape
# Out:
# (762, 150528)

# %%
num_
# Out:
# array([32, 43, 41, 43, 37, 40, 42, 43, 54, 40, 41, 38, 44, 42, 36, 37, 35,
#        35, 39])

# %%
import numpy as np
temp=np.asarray(temp)
temp.shape
# Out:
# (50176, 3)

# %%
from scipy.io import savemat
savemat('/content/gdrive/My Drive/Results_GAIT/data2.mat',{'fr':np.asarray(temp)})

# %%
nums=[]
for i in range(len(f[0])):
  nums.append(len(f[0][i]))
nums=np.asarray(nums)

# %%
from scipy.io import savemat
savemat('/content/gdrive/My Drive/Results_GAIT/num_2.mat',{'s':num_})

# %%
np.asarray(temp)
# Out:
# array([], dtype=float64)
